# %% [raw]
# ---
# title: "Linear Regression Quality Assurance"
# author: "Shazmeen Maroof"
# execute:
#   echo: false
# format:
#   html:
#     embed-resources: true
#     toc: true
#     toc-title: "Contents"
#     toc-location: left
#     html-math-method: katex
# ---

# %%
model = None
theta_0 = None
theta_1 = None
pipeline_runtime = None
x_data = None
y_data = None
y_predicted = None
residuals = None
w_stat = None
p_value = None
config = None
r_squared = None

# %% [markdown]
# ## Introduction
#
# This QA report is for a univariate linear regression pipeline run on the possum dataset taken from Kaggle. (Link to data: https://www.kaggle.com/datasets/abrambeyer/openintro-possum). The model aims to understand the relationship between posumm's head length and its total length. The report is created using Quarto, RStudio's multi-language version of R Markdown.
#
# ## Pipeline Configuration
#
# Below is the pipeline configuration used in generating this report. The convergence threshold determines when the model is considered to have finished training, and theta_0 and theta_1 are the regression model parameters, namely the y-intercept and gradient, respectively.

# %%
# Import numpy and pandas libraries to read the data, statsmodel to run regression and matplotlib and seaborn libraries to visualize the data
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt 
import seaborn as sns
import datetime
import yaml
from quarto import render
import plotly.express as px
from statsmodels.graphics.gofplots import qqplot
import matplotlib.pyplot as plt

# %% [markdown]
# ## Model Performance

# %%
display(Markdown(f"""Below we see the sumary output of regression analysis. The model has a coefficient of determination (R^2) of {r_squared}."""))
